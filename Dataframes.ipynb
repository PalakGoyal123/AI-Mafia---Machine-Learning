# %%
import pandas as pd
import numpy as np

# %%
from numpy.random import randn
np.random.seed(101)

# %%
pd.DataFrame?

# %% [markdown]
# index are rows and data is generated by  random function

# %%
df1 = pd.DataFrame(randn(5,4),index = 'A B C D E'.split(),columns = 'W X Y Z'.split())
df1
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
print(type(df1))
print(type(df1['W']))
print(type(df1['W']['A']))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# <class 'numpy.float64'>

# %% [markdown]
# # selection and indexing

# %%
df1['W']
# Out:
# A    2.706850
# B    0.651118
# C   -2.018168
# D    0.188695
# E    0.190794
# Name: W, dtype: float64

# %%
# we can pass a list of column names
df1[['W','X']]
# Out:
#           W         X
# A  2.706850  0.628133
# B  0.651118 -0.319318
# C -2.018168  0.740122
# D  0.188695 -0.758872
# E  0.190794  1.978757

# %%
df1.W
# Out:
# A    2.706850
# B    0.651118
# C   -2.018168
# D    0.188695
# E    0.190794
# Name: W, dtype: float64

# %%
df1['new'] = df1['W']+df1['X']#in this way we can create a a new column

# %%
df1.new
# Out:
# A    3.334983
# B    0.331800
# C   -1.278046
# D   -0.570177
# E    2.169552
# Name: new, dtype: float64

# %%
df1
# Out:
#           W         X         Y         Z       new
# A  2.706850  0.628133  0.907969  0.503826  3.334983
# B  0.651118 -0.319318 -0.848077  0.605965  0.331800
# C -2.018168  0.740122  0.528813 -0.589001 -1.278046
# D  0.188695 -0.758872 -0.933237  0.955057 -0.570177
# E  0.190794  1.978757  2.605967  0.683509  2.169552

# %% [markdown]
# # removing a column

# %%
# axis = 1 means column
df1.drop('new',axis = 1)
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df1
# Out:
#           W         X         Y         Z       new
# A  2.706850  0.628133  0.907969  0.503826  3.334983
# B  0.651118 -0.319318 -0.848077  0.605965  0.331800
# C -2.018168  0.740122  0.528813 -0.589001 -1.278046
# D  0.188695 -0.758872 -0.933237  0.955057 -0.570177
# E  0.190794  1.978757  2.605967  0.683509  2.169552

# %%
df1.drop('Z',axis = 1,inplace=True)

# %%
df1.drop('E',axis = 0)
# Out:
#           W         Z
# A  2.706850  0.503826
# B  0.651118  0.605965
# C -2.018168 -0.589001
# D  0.188695  0.955057

# %%
df1.loc['A']
# Out:
# W    2.706850
# Y    0.907969
# Z    0.503826
# Name: A, dtype: float64

# %%
df1.iloc[2]
# Out:
# W   -2.018168
# Y    0.528813
# Z   -0.589001
# Name: C, dtype: float64

# %% [markdown]
# ##conditional selection

# %%
df1
# Out:
#           W         Y         Z
# A  2.706850  0.907969  0.503826
# B  0.651118 -0.848077  0.605965
# C -2.018168  0.528813 -0.589001
# D  0.188695 -0.933237  0.955057
# E  0.190794  2.605967  0.683509

# %%
df1>0
# Out:
#        W      Y      Z
# A   True   True   True
# B   True  False   True
# C  False   True  False
# D   True  False   True
# E   True   True   True

# %%
df1[df1>0]
# Out:
#           W         Y         Z
# A  2.706850  0.907969  0.503826
# B  0.651118       NaN  0.605965
# C       NaN  0.528813       NaN
# D  0.188695       NaN  0.955057
# E  0.190794  2.605967  0.683509

# %%
#if dataframe w is greater than zero then only give me the df
df1[df1['W']>0]
# Out:
#           W         Y         Z
# A  2.706850  0.907969  0.503826
# B  0.651118 -0.848077  0.605965
# D  0.188695 -0.933237  0.955057
# E  0.190794  2.605967  0.683509
